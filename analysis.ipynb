# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create the dataset
data = {
    'Animal': ['Pig', 'Pig', 'Dog', 'Dog', 'Pig', 'Pig', 'Dog', 'Dog', 'Pig', 'Pig', 'Dog', 'Pig', 'Pig'],
    'Organ Type': ['Small Intestine', 'Small Intestine', 'Stomach', 'Stomach', 'Colon', 'Esophagus', 'Small Intestine', 'Stomach', 'Colon', 'Small Intestine', 'Stomach', 'Small Intestine', 'Esophagus'],
    'Delivery Method': ['Radial Microjet', 'Radial Microjet', 'Axial Microjet', 'Axial Microjet', 'Axial Microjet', 'Radial Microjet', 'Radial Microjet', 'Axial Microjet', 'Radial Microjet', 'Radial Microjet', 'Axial Microjet', 'Radial Microjet', 'Axial Microjet'],
    'Device Type': ['Tethered', 'Tethered', 'Untethered', 'Untethered', 'Tethered', 'Untethered', 'Tethered', 'Untethered', 'Tethered', 'Tethered', 'Untethered', 'Tethered', 'Untethered'],
    'Jet Pressure (bar)': [9.4, 12.0, 24.5, 20.0, 10.0, 8.0, 10.5, 18.0, 15.0, 11.0, 25.0, 13.0, 9.0],
    'Drug Type': ['Insulin', 'GLP-1 Analogue', 'Insulin', 'siRNA', 'Insulin', 'GLP-1 Analogue', 'siRNA', 'GLP-1 Analogue', 'siRNA', 'Insulin', 'siRNA', 'GLP-1 Analogue', 'Insulin'],
    'Bioavailability (%)': [69, 75, 90, 88, 78, 62, 81, 86, 77, 74, 89, 78, 68],
    'Control Bioavailability (%)': [70, 72, 85, 88, 76, 40, 79, 84, 50, 72, 87, 45, 66]
}

df = pd.DataFrame(data)

# %%
#| label: histogram 
# Plot 1: Histogram of Bioavailability
plt.figure(figsize=(10, 6))
plt.hist(df['Bioavailability (%)'], bins=8, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histogram of Bioavailability (%)', fontsize=14)
plt.xlabel('Bioavailability (%)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#| label: line-graph
# Plot 2: Line Graph of Jet Pressure vs Bioavailability
plt.figure(figsize=(10, 6))
plt.plot(df['Jet Pressure (bar)'], df['Bioavailability (%)'], marker='o', color='orange', label='Bioavailability')
plt.title('Jet Pressure vs Bioavailability', fontsize=14)
plt.xlabel('Jet Pressure (bar)', fontsize=12)
plt.ylabel('Bioavailability (%)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show()
